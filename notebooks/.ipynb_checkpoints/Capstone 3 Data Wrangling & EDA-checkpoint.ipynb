# %% [markdown]
# # Capstone 3 Data Wrangling & Exploratory Data Analysis

# %% [markdown]
# ## Contents
# 1. [Imports](#1.-Imports)
# 2. [Data Wrangling](#2.-Data-Wrangling)
#     * [2.1 Load Solar Power Generation & Weather Data](#2.1-Load-Solar-Power-Generation-&-Weather-Data)
#     * [2.2 Explore the Data](#2.2-Explore-the-Data)
#     * [2.3 Data Cleaning](#2.3-Data-Cleaning)
#     * [2.4 Merge DataFrames](#2.4-Merge-DataFrames)
#     * [2.5 Check for Missing Values & Duplicates](#2.5-Check-for-Missing-Values-&-Duplicates)
#     * [2.6 Create DateTime Features](#2.6-Create-DateTime-Features)
# 3. [Exploratory Data Analysis](#3.-Exploratory-Data-Analysis)
#     * [3.1 Plant Generation Data](#3.1-Plant-Generation-Data)
#         * [3.1.1 Average Hourly Power Generation Observations over a 5-day Period](#3.1.1-Average-Hourly-Power-Generation-Observations-over-a-5-day-Period)
#         * [3.1.2 DC Power and AC Power](#3.1.2-DC-Power-and-AC-Power)
#         * [3.1.3 Daily Yield and Total Yield](#3.1.3-Daily-Yield-and-Total-Yield)
#     * [3.2 Weather Data](#3.2-Weather-Data)
#         * [3.2.1 Average Hourly Weather Observations over a 5-day Period](#3.2.1-Average-Hourly-Weather-Observations-over-a-5-day-Period)
#         * [3.2.2 Ambient & Module Temperature, Irradiation](#3.2.2-Ambient-&-Module-Temperature,-Irradiation)
# 4. [Creating Plant Average Dataframes](#4.-Creating-Plant-Average-Dataframes)
# 5. [Target Feature Transformations](#5.-Target-Feature-Transformations)
#     * [5.1 Plant 1](#5.1-Plant-1)
#         * [5.1.1 Delta Daily Yield: 'delta_daily_yield'](#5.1.1-Delta-Daily-Yield:-'delta_daily_yield')
#         * [5.1.2 Removing Outliers: 'delta_daily_yield2'](#5.1.1-Removing-Outliers:-'delta_daily_yield2')
#         * [5.1.2 Correlations](#5.1.1-Correlations)
#     * [5.2 Plant 2](#5.2-Plant-2)
#         * [5.2.1 Delta Daily Yield: 'delta_daily_yield'](#5.2.1-Delta-Daily-Yield:-'delta_daily_yield')
#         * [5.2.2 Removing Outliers: 'delta_daily_yield2'](#5.2.1-Removing-Outliers:-'delta_daily_yield2')
#         * [5.2.2 Correlations](#5.2.1-Correlations)
# 6. [Save Plant Averages Data](#6.-Save-Plant-Averages-Data)

# %% [markdown]
# ## 1. Imports

# %%
import os
import re
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import colorcet as cc
from cycler import cycler
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## 2. Data Wrangling

# %% [markdown]
# ### 2.1 Load Solar Power Generation & Weather Data

# %%
generation1 = pd.read_csv('../data/Plant_1_Generation_Data.csv')
generation2 = pd.read_csv('../data/Plant_2_Generation_Data.csv')
weather1 = pd.read_csv('../data/Plant_1_Weather_Sensor_Data.csv')
weather2 = pd.read_csv('../data/Plant_2_Weather_Sensor_Data.csv')

# %% [markdown]
# ### 2.2 Explore the Data

# %%
generation1.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
generation2.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  2020-05-15 00:00:00   4136001  4UPUqMRk7TRMgml       0.0       0.0
# 1  2020-05-15 00:00:00   4136001  81aHJ1q11NBPMrL       0.0       0.0
# 2  2020-05-15 00:00:00   4136001  9kRcWv60rDACzjR       0.0       0.0
# 3  2020-05-15 00:00:00   4136001  Et9kgGMDl729KT4       0.0       0.0
# 4  2020-05-15 00:00:00   4136001  IQ2d7wF4YD8zU1Q       0.0       0.0
#
#    DAILY_YIELD   TOTAL_YIELD
# 0  9425.000000  2.429011e+06
# 1     0.000000  1.215279e+09
# 2  3075.333333  2.247720e+09
# 3   269.933333  1.704250e+06
# 4  3177.000000  1.994153e+07

# %%
weather1.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
weather2.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4136001  iq8k7ZNt4Mwm3w0            27.004764
# 1  2020-05-15 00:15:00   4136001  iq8k7ZNt4Mwm3w0            26.880811
# 2  2020-05-15 00:30:00   4136001  iq8k7ZNt4Mwm3w0            26.682055
# 3  2020-05-15 00:45:00   4136001  iq8k7ZNt4Mwm3w0            26.500589
# 4  2020-05-15 01:00:00   4136001  iq8k7ZNt4Mwm3w0            26.596148
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           25.060789          0.0
# 1           24.421869          0.0
# 2           24.427290          0.0
# 3           24.420678          0.0
# 4           25.088210          0.0

# %% [markdown]
# ### 2.3 Data Cleaning

# %%
generation1.DATE_TIME = pd.to_datetime(generation1.DATE_TIME,format='%d-%m-%Y %H:%M')
generation2.DATE_TIME = pd.to_datetime(generation2.DATE_TIME)
weather1.DATE_TIME = pd.to_datetime(weather1.DATE_TIME)
weather2.DATE_TIME = pd.to_datetime(weather2.DATE_TIME)

# %%
for df in [generation1, generation2, weather1, weather2]:
    print(df.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    68778 non-null  datetime64[ns]
#  1   PLANT_ID     68778 non-null  int64
#  2   SOURCE_KEY   68778 non-null  object
#  3   DC_POWER     68778 non-null  float64
#  4   AC_POWER     68778 non-null  float64
#  5   DAILY_YIELD  68778 non-null  float64
#  6   TOTAL_YIELD  68778 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 3.7+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67698 entries, 0 to 67697
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    67698 non-null  datetime64[ns]
#  1   PLANT_ID     67698 non-null  int64
#  2   SOURCE_KEY   67698 non-null  object
#  3   DC_POWER     67698 non-null  float64
#  4   AC_POWER     67698 non-null  float64
#  5   DAILY_YIELD  67698 non-null  float64
#  6   TOTAL_YIELD  67698 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 3.6+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3182 non-null   datetime64[ns]
#  1   PLANT_ID             3182 non-null   int64
#  2   SOURCE_KEY           3182 non-null   object
#  3   AMBIENT_TEMPERATURE  3182 non-null   float64
#  4   MODULE_TEMPERATURE   3182 non-null   float64
#  5   IRRADIATION          3182 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 149.3+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3259 entries, 0 to 3258
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3259 non-null   datetime64[ns]
#  1   PLANT_ID             3259 non-null   int64
#  2   SOURCE_KEY           3259 non-null   object
#  3   AMBIENT_TEMPERATURE  3259 non-null   float64
#  4   MODULE_TEMPERATURE   3259 non-null   float64
#  5   IRRADIATION          3259 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 152.9+ KB
# None

# %%
for df in [generation1, generation2, weather1, weather2]:
    print(df.DATE_TIME.head(), "\n")
# Out:
# 0   2020-05-15
# 1   2020-05-15
# 2   2020-05-15
# 3   2020-05-15
# 4   2020-05-15
# Name: DATE_TIME, dtype: datetime64[ns]
#
# 0   2020-05-15
# 1   2020-05-15
# 2   2020-05-15
# 3   2020-05-15
# 4   2020-05-15
# Name: DATE_TIME, dtype: datetime64[ns]
#
# 0   2020-05-15 00:00:00
# 1   2020-05-15 00:15:00
# 2   2020-05-15 00:30:00
# 3   2020-05-15 00:45:00
# 4   2020-05-15 01:00:00
# Name: DATE_TIME, dtype: datetime64[ns]
#
# 0   2020-05-15 00:00:00
# 1   2020-05-15 00:15:00
# 2   2020-05-15 00:30:00
# 3   2020-05-15 00:45:00
# 4   2020-05-15 01:00:00
# Name: DATE_TIME, dtype: datetime64[ns]

# %%
for df in [generation1, generation2, weather1, weather2]:
    print(df.isna().sum(), "\n")
# Out:
# DATE_TIME      0
# PLANT_ID       0
# SOURCE_KEY     0
# DC_POWER       0
# AC_POWER       0
# DAILY_YIELD    0
# TOTAL_YIELD    0
# dtype: int64
#
# DATE_TIME      0
# PLANT_ID       0
# SOURCE_KEY     0
# DC_POWER       0
# AC_POWER       0
# DAILY_YIELD    0
# TOTAL_YIELD    0
# dtype: int64
#
# DATE_TIME              0
# PLANT_ID               0
# SOURCE_KEY             0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64
#
# DATE_TIME              0
# PLANT_ID               0
# SOURCE_KEY             0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %% [markdown]
# ### 2.4 Merge DataFrames

# %%
# Pre-merge prep: drop PLANT_ID and SOURCE_KEY in weather data
weather1.drop(['PLANT_ID','SOURCE_KEY'],axis=1,inplace=True)
weather2.drop(['PLANT_ID','SOURCE_KEY'],axis=1,inplace=True)

# %%
plant_df1 = pd.merge(generation1,weather1,how='left',on='DATE_TIME')
plant_df2 = pd.merge(generation2,weather2,how='left',on='DATE_TIME')

# %%
# # drop PLANT_ID_y and SOURCE_KEY_y
# plant_df1.drop(['PLANT_ID_y','SOURCE_KEY_y'],axis=1,inplace=True)
# plant_df2.drop(['PLANT_ID_y','SOURCE_KEY_y'],axis=1,inplace=True)

# %%
plant_df1.head()
# Out:
#    DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0 2020-05-15   4135001  1BY6WEcLGh8j5v7       0.0       0.0          0.0
# 1 2020-05-15   4135001  1IF53ai7Xc0U56Y       0.0       0.0          0.0
# 2 2020-05-15   4135001  3PZuoBAID5Wc2HD       0.0       0.0          0.0
# 3 2020-05-15   4135001  7JYdWkrLSPkdwr4       0.0       0.0          0.0
# 4 2020-05-15   4135001  McdE0feGgRqW7Ca       0.0       0.0          0.0
#
#    TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0    6259559.0            25.184316           22.857507          0.0
# 1    6183645.0            25.184316           22.857507          0.0
# 2    6987759.0            25.184316           22.857507          0.0
# 3    7602960.0            25.184316           22.857507          0.0
# 4    7158964.0            25.184316           22.857507          0.0

# %%
plant_df2.head()
# Out:
#    DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0 2020-05-15   4136001  4UPUqMRk7TRMgml       0.0       0.0  9425.000000
# 1 2020-05-15   4136001  81aHJ1q11NBPMrL       0.0       0.0     0.000000
# 2 2020-05-15   4136001  9kRcWv60rDACzjR       0.0       0.0  3075.333333
# 3 2020-05-15   4136001  Et9kgGMDl729KT4       0.0       0.0   269.933333
# 4 2020-05-15   4136001  IQ2d7wF4YD8zU1Q       0.0       0.0  3177.000000
#
#     TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0  2.429011e+06            27.004764           25.060789          0.0
# 1  1.215279e+09            27.004764           25.060789          0.0
# 2  2.247720e+09            27.004764           25.060789          0.0
# 3  1.704250e+06            27.004764           25.060789          0.0
# 4  1.994153e+07            27.004764           25.060789          0.0

# %% [markdown]
# ### 2.5 Check for Missing Values & Duplicates

# %%
plant_df1.isna().sum()
# Out:
# DATE_TIME              0
# PLANT_ID               0
# SOURCE_KEY             0
# DC_POWER               0
# AC_POWER               0
# DAILY_YIELD            0
# TOTAL_YIELD            0
# AMBIENT_TEMPERATURE    4
# MODULE_TEMPERATURE     4
# IRRADIATION            4
# dtype: int64

# %%
plant_df1[plant_df1['IRRADIATION'].isna()]
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 38544 2020-06-03 14:00:00   4135001  1IF53ai7Xc0U56Y    7003.0     685.8
# 38545 2020-06-03 14:00:00   4135001  adLQvlD726eNBSB    7204.0     705.4
# 38546 2020-06-03 14:00:00   4135001  wCURE6d3bPkepu2    7545.0     738.7
# 38547 2020-06-03 14:00:00   4135001  z9Y9gH1T5YWrNuG    7946.0     777.8
#
#        DAILY_YIELD  TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 38544       5601.0    6330385.0                  NaN                 NaN
# 38545       5685.0    6419961.0                  NaN                 NaN
# 38546       5579.0    6928448.0                  NaN                 NaN
# 38547       5541.0    7152815.0                  NaN                 NaN
#
#        IRRADIATION
# 38544          NaN
# 38545          NaN
# 38546          NaN
# 38547          NaN

# %%
plant_df1.dropna(inplace=True)
plant_df1.isna().sum()
# Out:
# DATE_TIME              0
# PLANT_ID               0
# SOURCE_KEY             0
# DC_POWER               0
# AC_POWER               0
# DAILY_YIELD            0
# TOTAL_YIELD            0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %%
# plant_df2.isna().sum()

# %%
# print(plant_df1[plant_df1.duplicated()])
# print(plant_df2[plant_df2.duplicated()])

# %%
plant_df1.columns = [col.lower() for col in plant_df1.columns]
plant_df2.columns = [col.lower() for col in plant_df2.columns]

# %% [markdown]
# ### 2.6 Create DateTime Features

# %%
for df in [plant_df1, plant_df2]:
    df['date'] = df['date_time'].dt.date
    df['time'] = df['date_time'].dt.time
    df['hour'] = df['date_time'].dt.hour
    df['day'] = df['date_time'].dt.day
    df['weekday'] = df['date_time'].dt.day_name()
    df['month'] = df['date_time'].dt.month
    df['year'] = df['date_time'].dt.year

# %%
plant_df1.columns
# Out:
# Index(['date_time', 'plant_id', 'source_key', 'dc_power', 'ac_power',
#        'daily_yield', 'total_yield', 'ambient_temperature',
#        'module_temperature', 'irradiation', 'date', 'time', 'hour', 'day',
#        'weekday', 'month', 'year'],
#       dtype='object')

# %%
## Save Cleaned Data

print(plant_df1.shape)
print(plant_df2.shape)

# plant_df1.to_csv('../data/plant1_cleaned.csv',index=False)
# plant_df2.to_csv('../data/plant2_cleaned.csv',index=False)
# Out:
# (68774, 17)
# (67698, 17)

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# ### 3.1 Plant Generation Data

# %%
print('\nNumber of Inverters in Plant 1: ',len(plant_df1.source_key.unique()))
print('\nNumber of Inverters in Plant 2: ',len(plant_df2.source_key.unique()))
# Out:
# Number of Inverters in Plant 1:  22
#
# Number of Inverters in Plant 2:  22

# %%
plant_df1.date = plant_df1.date.astype(str)
plant_df2.date = plant_df2.date.astype(str)
plant_df1.time = plant_df1.time.astype(str)
plant_df2.time = plant_df2.time.astype(str)

# %% [markdown]
# #### 3.1.1 Average Hourly Power Generation Observations over a 5-day Period

# %%
# Plant 1: Power Generation Variables to plot
vars = ['dc_power','ac_power','daily_yield','total_yield'] 

fig, axs = plt.subplots(4, sharex=True, sharey=False, figsize=(11,6))
fig.suptitle('Plant 1: Average Hourly Trend of Power Generation Variables', fontsize=14)

for i in range(4):
    axs[i].plot(plant_df1.set_index('date_time').resample('1H').mean()['2020-05-22':'2020-05-26'][vars[i]], label='Mean')
    axs[i].plot(plant_df1.set_index('date_time').resample('1H').max()['2020-05-22':'2020-05-26'][vars[i]], label='Maximum')
    axs[i].plot(plant_df1.set_index('date_time').resample('1H').min()['2020-05-22':'2020-05-26'][vars[i]], label='Minimum')
    axs[i].set_title(vars[i])
fig.subplots_adjust(hspace=0.3)
# fig.text(0.04, 0.5, 'KW', va='center', rotation='vertical', fontsize=12)
fig.text(0.51, 0.04, 'Time', ha='center', fontsize=12)
plt.legend(loc='upper center', ncol=3)
plt.tight_layout();

# Plant 2: Power Generation Variables to plot
vars = ['dc_power','ac_power','daily_yield','total_yield'] 

fig, axs = plt.subplots(4, sharex=True, sharey=False, figsize=(11,6))
fig.suptitle('Plant 2: Average Hourly Trend of Power Generation Variables', fontsize=14)

for i in range(4):
    axs[i].plot(plant_df2.set_index('date_time').resample('1H').mean()['2020-05-22':'2020-05-26'][vars[i]], label='Mean')
    axs[i].plot(plant_df2.set_index('date_time').resample('1H').max()['2020-05-22':'2020-05-26'][vars[i]], label='Maximum')
    axs[i].plot(plant_df2.set_index('date_time').resample('1H').min()['2020-05-22':'2020-05-26'][vars[i]], label='Minimum')
    axs[i].set_title(vars[i])
fig.subplots_adjust(hspace=0.3)
# fig.text(0.04, 0.5, 'KW', va='center', rotation='vertical', fontsize=12)
fig.text(0.51, 0.04, 'Time', ha='center', fontsize=12)
plt.legend(loc='upper center', ncol=3)
plt.tight_layout();

# %% [markdown]
# #### 3.1.2 DC Power and AC Power

# %% [markdown]
# ***
#
# **Inverter Performance**
#
# A solar panel produces DC power (direct current energy) and inverters convert it into AC power for residential and industrial use.
#
# - power out = AC power
# - power in = DC power
# - efficiency = power out / power in
#
# **Inverter/Conversion Efficiency**
# - Inverter/Conversion efficiency is given by the ratio of AC power generated by the
# inverter to the DC power generated by the PV array system.
# ***

# %%
plant_df1.plot(x='date',y=['dc_power','ac_power'],figsize=(12,3))
plt.title('Plant 1: AC and DC Power over time')
plt.tight_layout();

plant_df2.plot(x='date',y=['dc_power','ac_power'],figsize=(12,3))
plt.title('Plant 2: AC and DC Power over time')
plt.tight_layout();

# %%
plant1_dc = plant_df1[plant_df1.dc_power > 0]['dc_power'].values
plant1_ac = plant_df1[plant_df1.ac_power > 0]['ac_power'].values
dc_ac_ratio1 = np.mean(plant1_ac)/np.mean(plant1_dc) * 100

plant2_dc = plant_df2[plant_df2.dc_power > 0]['dc_power'].values
plant2_ac = plant_df2[plant_df2.ac_power > 0]['ac_power'].values
dc_ac_ratio2 = np.mean(plant2_ac)/np.mean(plant2_dc) * 100

efficiency_conversion_ratio = dc_ac_ratio2/dc_ac_ratio1

print("Plant 1's AC/DC ratio: ", dc_ac_ratio1)
print("Plant 2's AC/DC ratio: ", dc_ac_ratio2)
print("Efficiency Converversion Ratio: ", efficiency_conversion_ratio)
# Out:
# Plant 1's AC/DC ratio:  9.779504980482011
# Plant 2's AC/DC ratio:  97.80134066733811
# Efficiency Converversion Ratio:  10.000643270035708

# %% [markdown]
# ***
#
# **Note:** The difference between plant 1's DC and AC power seems peculiar: DC power is around 10 times AC power. Conversion efficiency for solar inverters are typically around 97% to 99% meaning energy loss is relatively minor. It is either that plant 1 experiences substantial loss from DC-AC conversion (perhaps due to faulty equiptment) or caused by human error during the data collection phase. We're going to rescale plant 1's DC power by dividing by our conversion efficiency ratio that we found above.
#
# ***

# %%
plant_df1['dc_power'] = plant_df1['dc_power'] / efficiency_conversion_ratio

plant_df1.plot(x='date',y=['dc_power','ac_power'],figsize=(12,3))
plt.title('Plant 1: AC and DC Power over time (Rescaled using Conversion Factor)')
plt.tight_layout();

# %%
p1 = plant_df1.groupby('date_time').mean().reset_index()
p1['time']=p1['date_time'].dt.time
p2 = plant_df2.groupby('date_time').mean().reset_index()
p2['time']=p2['date_time'].dt.time

hourly_ticks = [60*60*i for i in range(0,24,3)]

fig,(ax1,ax2) = plt.subplots(1,2,sharey=True,figsize=(12,5))
p1.set_index('time')[['dc_power','ac_power']].plot(style='-',xticks=hourly_ticks,title='Plant 1: AC/DC Power over Day Hours',ax=ax1)
p1.groupby('time')['dc_power'].agg('mean').plot(color='cyan',ax=ax1)
p1.groupby('time')['ac_power'].agg('mean').plot(color='black',ax=ax1)
plt.tight_layout();

p2.set_index('time')[['dc_power','ac_power']].plot(style='-',xticks=hourly_ticks,title='Plant 2: AC/DC Power over Day Hours',ax=ax2)
p2.groupby('time')['dc_power'].agg('mean').plot(color='cyan',ax=ax2)
p2.groupby('time')['ac_power'].agg('mean').plot(color='black',ax=ax2)
plt.tight_layout();

# %% [markdown]
# ***
#
# **Note:** AC/DC power generation starts at ~6AM and ends at ~6PM (day light hours). We see a nice bell-shaped curve in plant 1; however, it seems that plant 2's AC/DC power seems to be capped at a threshold. We will take a look at how each inverter works during day hours to get a better understanding of what is going on. We will focus on DC power generation.
#
# ***

# %% [markdown]
# **Which inverter is underperforming?**

# %%
p1_dc_pwr = plant_df1.groupby(['time','source_key'])['dc_power'].mean().unstack()
p2_dc_pwr = plant_df2.groupby(['time','source_key'])['dc_power'].mean().unstack()

# sns.set_style('darkgrid')
colors = sns.color_palette(cc.glasbey_light,22)
cy = cycler('color', colors)

fig,(ax1,ax2) = plt.subplots(1,2,sharey=True,figsize=(12,7))
ax1.set_prop_cycle(cy)
ax1.plot(p1_dc_pwr,linewidth=2)
ax1.set_title('Plant 1: DC Power Generation per Inverter by Hour')
ax1.legend(p1_dc_pwr.columns,loc=9,bbox_to_anchor=(0.5,-0.25),ncol=2)
ax1.set_xticks(np.arange(0,100,10))
ax1.tick_params(axis='x',rotation=90)
ax1.set_xticks(np.arange(0,100,10))

ax2.set_prop_cycle(cy)
ax2.plot(p2_dc_pwr,linewidth=2)
ax2.set_title('Plant 2: DC Power Generation per Inverter by Hour')
ax2.legend(p2_dc_pwr.columns,loc=9,bbox_to_anchor=(0.5,-0.25),ncol=2)
ax2.set_xticks(np.arange(0,100,10))
ax2.tick_params(axis='x',rotation=90)
ax2.set_xticks(np.arange(0,100,10))
plt.tight_layout();

# %% [markdown]
# ***
#
# **Note:** Plant 1's DC power generation per inverters are tightly grouped. Again, we see much more variation in plant 2's inverters. There are 2 inverters in plant 1 that have slightly noticeable/visible lower signals while 4 inverters in plant 2 that are substantially lower.
# - Plant 1's underperforming inverters: "1BY6WEcLGh8j5v7" and "bvBOhCH3iADSZry".
# - Plant 2's underperforming inverters: "Et9kgGMDl729KT4", "LYwnQax7tkwH5Cb", "Quc1TzYxW2pYoWX", and "rrq4fwE8jgrTyWY"
#
# ***

# %% [markdown]
# #### 3.1.3 Daily Yield and Total Yield

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(12,5))
plant_df1.plot(x='date',y='daily_yield',color='orange',ax=ax1)
plant_df1.plot(x='date',y='total_yield',color='grey',ax=ax2)
ax1.title.set_text('Plant 1: Daily Yield')
ax2.title.set_text('Plant 1: Total Yield')
plt.tight_layout();

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(12,5))
plant_df2.plot(x='date',y='daily_yield',color='orange',ax=ax1)
plant_df2.plot(x='date',y='total_yield',color='grey',ax=ax2)
ax1.title.set_text('Plant 2: Daily Yield')
ax2.title.set_text('Plant 2: Total Yield')
plt.tight_layout();

# %% [markdown]
# ***
#
# **Note:** It looks like daily yield is the cumulative sum totals for each day while total yield is the cumulative sum for the entire 34 day period. We see wider/thicker bands within the daily fluctuations in plant 2's daily yield. It seems that plant 1's total yield seems to trend upwards while plant 2's total yield is fixed within a range between 0 and 2.
#
# ***

# %% [markdown]
# ### 3.2 Weather Data

# %% [markdown]
# #### 3.2.1 Average Hourly Weather Observations over a 5-day Period

# %%
# Plant 1: Weather Variables to plot
vars = ['ambient_temperature','module_temperature','irradiation'] 

fig, axs = plt.subplots(3, sharex=True, sharey=False, figsize=(11,5))
fig.suptitle('Plant 1: Average Hourly Trend of Weather Variables', fontsize=14)

for i in range(3):
    axs[i].plot(plant_df1.set_index('date_time').resample('1H').mean()['2020-05-22':'2020-05-26'][vars[i]], label='Mean')
    axs[i].plot(plant_df1.set_index('date_time').resample('1H').max()['2020-05-22':'2020-05-26'][vars[i]], label='Maximum')
    axs[i].plot(plant_df1.set_index('date_time').resample('1H').min()['2020-05-22':'2020-05-26'][vars[i]], label='Minimum')
    axs[i].set_title(vars[i])
fig.subplots_adjust(hspace=0.3)
# fig.text(0.04, 0.5, 'KW', va='center', rotation='vertical', fontsize=12)
fig.text(0.51, 0.04, 'Time', ha='center', fontsize=12)
plt.legend(loc='upper center', ncol=3)
plt.tight_layout();

# Plant 2: Weather Variables to plot
vars = ['ambient_temperature','module_temperature','irradiation'] 

fig, axs = plt.subplots(3, sharex=True, sharey=False, figsize=(11,5))
fig.suptitle('Plant 2: Average Hourly Trend of Weather Variables', fontsize=14)

for i in range(3):
    axs[i].plot(plant_df2.set_index('date_time').resample('1H').mean()['2020-05-22':'2020-05-26'][vars[i]], label='Mean')
    axs[i].plot(plant_df2.set_index('date_time').resample('1H').max()['2020-05-22':'2020-05-26'][vars[i]], label='Maximum')
    axs[i].plot(plant_df2.set_index('date_time').resample('1H').min()['2020-05-22':'2020-05-26'][vars[i]], label='Minimum')
    axs[i].set_title(vars[i])
fig.subplots_adjust(hspace=0.3)
# fig.text(0.04, 0.5, 'KW', va='center', rotation='vertical', fontsize=12)
fig.text(0.51, 0.04, 'Time', ha='center', fontsize=12)
plt.legend(loc='upper center', ncol=3)
plt.tight_layout();

# %% [markdown]
# #### 3.2.2 Ambient & Module Temperature, Irradiation

# %%
sns.set_style('white')

p1 = plant_df1.groupby('date_time').sum().reset_index()
p1['time']=p1['date_time'].dt.time
hourly_ticks = [60*60*i for i in range(0,24,2)]
sns.set_style('white')
p1.set_index('time')[['ambient_temperature','module_temperature']].plot(style= '.',figsize=(12,3),xticks=hourly_ticks,title='Plant 1: Ambient and Module Temperature over day hours')
p1.groupby('time')['ambient_temperature'].agg('mean').plot(color='cyan')
p1.groupby('time')['module_temperature'].agg('mean').plot(color='yellow')
plt.tight_layout();

df_gen1 = plant_df1.groupby('date_time').mean().reset_index()
df_gen1.plot(x ='date_time',y=['ambient_temperature','module_temperature'],title='Plant 1: Ambient and Module Temperature over time',figsize=(12,3))
# plt.ylabel('Temperature')
plt.tight_layout();

df_gen1.plot(x ='date_time',y=['irradiation'],title='Plant 1: Irradiation over time',color='green',figsize=(12,3))
plt.tight_layout();

# %%
p2 = plant_df2.groupby('date_time').sum().reset_index()
p2['time']=p2['date_time'].dt.time
p2.set_index('time')[['ambient_temperature','module_temperature']].plot(style= '.',figsize=(12,3),xticks=hourly_ticks,title='Plant 2: Ambient and Module Temperature over day hours')
p2.groupby('time')['ambient_temperature'].agg('mean').plot(color='cyan')
p2.groupby('time')['module_temperature'].agg('mean').plot(color='yellow')
plt.tight_layout();

df_gen2 = plant_df2.groupby('date_time').mean().reset_index()
df_gen2.plot(x ='date_time',y=['ambient_temperature','module_temperature'],title='Plant 2: Ambient and Module Temperature over time',figsize=(12,3))
# plt.ylabel('Temperature')
plt.tight_layout();

df_gen2.plot(x ='date_time',y=['irradiation'],title='Plant 2: Irradiation over time',color='green',figsize=(12,3))
plt.tight_layout();

# %% [markdown]
# ## 4. Creating Plant Average Dataframes

# %%
plant1_avg = plant_df1.groupby(['date_time']).agg('mean').reset_index()
plant2_avg = plant_df2.groupby(['date_time']).agg('mean').reset_index()

print(plant1_avg.shape)
print(plant2_avg.shape)
# Out:
# (3157, 13)
# (3259, 13)

# %%
plant1_avg.describe()
# Out:
#         plant_id     dc_power     ac_power  daily_yield   total_yield  \
# count     3157.0  3157.000000  3157.000000  3157.000000  3.157000e+03
# mean   4135001.0   311.710849   304.857459  3324.402716  6.977422e+06
# std          0.0   400.216841   391.090163  3045.292432  7.513782e+04
# min    4135001.0     0.000000     0.000000     0.000000  6.635010e+06
# 25%    4135001.0     0.000000     0.000000     4.124188  6.917337e+06
# 50%    4135001.0    38.316610    37.040016  3009.619318  6.981686e+06
# 75%    4135001.0   638.185733   625.096023  6094.517045  7.045256e+06
# max    4135001.0  1358.720714  1325.009659  8807.727273  7.097398e+06
#
#        ambient_temperature  module_temperature  irradiation         hour  \
# count          3157.000000         3157.000000  3157.000000  3157.000000
# mean             25.560257           31.175453     0.230103    11.626227
# std               3.351059           12.272685     0.301348     6.867083
# min              20.398505           18.140415     0.000000     0.000000
# 25%              22.739895           21.130249     0.000000     6.000000
# 50%              24.680324           24.801971     0.027748    12.000000
# 75%              27.941221           41.449481     0.451576    18.000000
# max              35.252486           65.545714     1.221652    23.000000
#
#                day        month    year
# count  3157.000000  3157.000000  3157.0
# mean     15.783022     5.515996  2020.0
# std       8.561164     0.499823     0.0
# min       1.000000     5.000000  2020.0
# 25%       9.000000     5.000000  2020.0
# 50%      16.000000     6.000000  2020.0
# 75%      23.000000     6.000000  2020.0
# max      31.000000     6.000000  2020.0

# %%
plant2_avg.describe()
# Out:
#         plant_id     dc_power     ac_power  daily_yield   total_yield  \
# count     3259.0  3259.000000  3259.000000  3259.000000  3.259000e+03
# mean   4136001.0   248.818478   243.339215  3283.334245  6.636655e+08
# std          0.0   313.503377   306.485223  2339.704265  6.796735e+07
# min    4136001.0     0.000000     0.000000     0.000000  0.000000e+00
# 25%    4136001.0     0.000000     0.000000   902.791991  6.450146e+08
# 50%    4136001.0    23.618307    22.809630  3487.807792  6.451436e+08
# 75%    4136001.0   533.909648   522.740660  5257.590909  6.746497e+08
# max    4136001.0  1210.477576  1180.898203  7923.055556  8.769846e+08
#
#        ambient_temperature  module_temperature  irradiation         hour  \
# count          3259.000000         3259.000000  3259.000000  3259.000000
# mean             28.069400           32.772408     0.232737    11.491255
# std               4.061556           11.344034     0.312693     6.923916
# min              20.942385           20.265123     0.000000     0.000000
# 25%              24.602135           23.716881     0.000000     5.000000
# 50%              26.981263           27.534606     0.019040    11.000000
# 75%              31.056757           40.480653     0.438717    17.500000
# max              39.181638           66.635953     1.098766    23.000000
#
#                day        month    year
# count  3259.000000  3259.000000  3259.0
# mean     16.003989     5.500153  2020.0
# std       8.541578     0.500077     0.0
# min       1.000000     5.000000  2020.0
# 25%       9.000000     5.000000  2020.0
# 50%      16.000000     6.000000  2020.0
# 75%      23.000000     6.000000  2020.0
# max      31.000000     6.000000  2020.0

# %%
plant1_avg[['dc_power','ac_power','daily_yield','total_yield','ambient_temperature','module_temperature','irradiation']][plant1_avg.dc_power > 0].hist(figsize=(8,8),bins=20)
plt.tight_layout();

# %%
plant2_avg[['dc_power','ac_power','daily_yield','total_yield','ambient_temperature','module_temperature','irradiation']][plant2_avg.dc_power > 0].hist(figsize=(8,8),bins=20)
plt.tight_layout();

# %% [markdown]
# ## 5. Target Feature Transformations

# %% [markdown]
# ### 5.1 Plant 1

# %% [markdown]
# #### 5.1.1 Delta Daily Yield: 'delta_daily_yield'

# %%
p1_delta = plant1_avg[['daily_yield']]
p1_delta['delta_daily_yield'] = p1_delta.daily_yield.diff()
p1_delta['delta_daily_yield'].iloc[0] = 0
p1_delta[p1_delta < 0] = 0

# %%
plant1_avg['delta_daily_yield'] = p1_delta.delta_daily_yield

# plant1_avg['delta_daily_yield'].plot(figsize=(12,3))
# plt.tight_layout();

# %%
plant1_avg['delta_daily_yield'].describe()
# Out:
# count    3157.000000
# mean       77.500585
# std       113.079115
# min         0.000000
# 25%         0.000000
# 50%         9.516234
# 75%       155.973214
# max      3079.298485
# Name: delta_daily_yield, dtype: float64

# %% [markdown]
# #### 5.1.2 Removing Outliers: 'delta_daily_yield2'

# %%
delta_dy = plant1_avg['delta_daily_yield'].copy()

delta_dy_mean = delta_dy.mean()
delta_dy_std = delta_dy.std()

print('delta daily yield mean for Plant 1: ',delta_dy_mean)
print('delta daily yield standard deviation for Plant 1: ',delta_dy_std)
# Out:
# delta daily yield mean for Plant 1:  77.50058541632838
# delta daily yield standard deviation for Plant 1:  113.07911497371943

# %%
ax = delta_dy.plot(figsize=(12,3))
ax.axhline(delta_dy_mean + delta_dy_std * 3, ls='--', c='r')
# ax.axhline(dd2_mean - dd2_std * 3, ls='--', c='r')
plt.tight_layout();

# %%
# Replace outliers with the median value
outliers = delta_dy > (delta_dy_std * 3)
delta_dy_centered = delta_dy
delta_dy_fixed = delta_dy.copy()
delta_dy_fixed[outliers] = np.median(delta_dy_fixed)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4),sharey=True)
delta_dy_centered.plot(ax=ax1)
delta_dy_fixed.plot(ax=ax2)
ax1.title.set_text('Before Replacement')
ax2.title.set_text('After Replacement')
plt.tight_layout();

# %%
plant1_avg['delta_daily_yield2'] = delta_dy_fixed

# %%
plant1_avg['delta_daily_yield2'].describe()
# Out:
# count    3157.000000
# mean       75.807964
# std        97.174675
# min         0.000000
# 25%         0.000000
# 50%         9.516234
# 75%       155.526786
# max       318.896104
# Name: delta_daily_yield2, dtype: float64

# %% [markdown]
# ### 5.1.3 Correlations

# %%
plant1_corr = plant1_avg[['dc_power','ac_power','daily_yield','delta_daily_yield','delta_daily_yield2','ambient_temperature','module_temperature','irradiation']]
plt.subplots(figsize=(10,6))
sns.heatmap(plant1_corr.corr(),annot=True,cmap='YlGnBu',mask=(np.triu(plant1_corr.corr(),+1)));

# %% [markdown]
# ### 5.2 Plant 2

# %% [markdown]
# ### 5.2.1 Delta Daily Yield: 'delta_daily_yield'

# %%
p2_delta = plant2_avg[['daily_yield']]
p2_delta['delta_daily_yield'] = p2_delta.daily_yield.diff()
p2_delta['delta_daily_yield'].iloc[0] = 0
p2_delta[p2_delta < 0] = 0

# %%
plant2_avg['delta_daily_yield'] = p2_delta.delta_daily_yield

# %%
plant2_avg['delta_daily_yield'].describe()
# Out:
# count    3259.000000
# mean       76.166874
# std       194.124418
# min         0.000000
# 25%         0.000000
# 50%         6.010823
# 75%       131.424735
# max      4554.474242
# Name: delta_daily_yield, dtype: float64

# %% [markdown]
# ### 5.2.2 Removing Outliers: 'delta_daily_yield2'

# %%
delta_dy = plant2_avg['delta_daily_yield'].copy()

delta_dy_mean = delta_dy.mean()
delta_dy_std = delta_dy.std()

print('delta daily yield mean for Plant 2: ',delta_dy_mean)
print('delta daily yield standard deviation for Plant 2: ',delta_dy_std)
# Out:
# delta daily yield mean for Plant 2:  76.16687427672386
# delta daily yield standard deviation for Plant 2:  194.1244180181867

# %%
ax = delta_dy.plot(figsize=(12,3))
ax.axhline(delta_dy_mean + delta_dy_std * 3, ls='--', c='r')
# ax.axhline(dd2_mean - dd2_std * 3, ls='--', c='r')
plt.tight_layout();

# %%
# Replace outliers with the median value
outliers = delta_dy > (delta_dy_std * 3)
delta_dy_centered = delta_dy
delta_dy_fixed = delta_dy.copy()
delta_dy_fixed[outliers] = np.median(delta_dy_fixed)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4),sharey=True)
delta_dy_centered.plot(ax=ax1)
delta_dy_fixed.plot(ax=ax2)
ax1.title.set_text('Before Replacement')
ax2.title.set_text('After Replacement')
plt.tight_layout();

# %%
plant2_avg['delta_daily_yield2'] = delta_dy_fixed

# %% [markdown]
# ### 5.2.3 Correlations

# %%
plant2_corr = plant2_avg[['dc_power','ac_power','daily_yield','delta_daily_yield','delta_daily_yield2','ambient_temperature','module_temperature','irradiation']]
plt.subplots(figsize=(10,6))
sns.heatmap(plant2_corr.corr(),annot=True,cmap='YlGnBu',mask=(np.triu(plant2_corr.corr(),+1)));

# %% [markdown]
# ## 6. Save Plant Averages Data

# %%
print(plant1_avg.shape)
print(plant2_avg.shape)

# plant1_avg.to_csv('../data/plant1_avg.csv',index=False)
# plant2_avg.to_csv('../data/plant2_avg.csv',index=False)
# Out:
# (3157, 15)
# (3259, 15)
